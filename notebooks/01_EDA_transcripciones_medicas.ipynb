# %% [markdown]
# # Medical Transcription Analysis Report
#
# **Objective:** Analyze the `mtsamples.csv` dataset to determine data quality, class balance, and text characteristics for NLP modeling.
#
# ---

# %%
# Install dependencies (if running from notebooks/ directory)
# !pip install -r ../requirements.txt
# %pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1. Environment Configuration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# NLTK Downloads
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)

# Visualization Settings
plt.style.use('seaborn-v0_8-whitegrid')
pd.set_option('display.max_colwidth', 50)

# %% [markdown]
# ## 2. Data Loading and Cleaning Executive Summary

# %%
DATA_PATH = '../data/raw/mtsamples.csv'

try:
    df = pd.read_csv(DATA_PATH)
    
    # Remove unnecessary column if exists
    if 'Unnamed: 0' in df.columns:
        df = df.drop(columns=['Unnamed: 0'])
        
    initial_rows = len(df)

    # 1. Deduplication (Critical for preventing data leakage)
    df_deduplicated = df.drop_duplicates(subset=['transcription'])
    duplicates_dropped = initial_rows - len(df_deduplicated)

    # 2. Drop Missing Values
    df_clean = df_deduplicated.dropna(subset=['transcription', 'medical_specialty']).reset_index(drop=True)
    final_rows = len(df_clean)
    nulls_dropped = len(df_deduplicated) - final_rows
    total_dropped = initial_rows - final_rows
    
    print("Data Cleaning Summary:")
    print("="*30)
    print(f"Original Rows:      {initial_rows:,}")
    print(f"Duplicates Dropped: {duplicates_dropped:,}")
    print(f"Nulls Dropped:      {nulls_dropped:,}")
    print(f"Final Clean Rows:   {final_rows:,}")
    print("="*30)

    # Real Data Sample
    print("\nReal Data Sample (Complexity Check):")
    print("-"*30)
    sample_idx = 0
    print(f"Specialty: {df_clean.loc[sample_idx, 'medical_specialty']}\n")
    print(f"Transcription:\n{df_clean.loc[sample_idx, 'transcription']}")
    print("-"*30)

except Exception as e:
    print(f"Error loading dataset: {e}")
# Out:
# Data Cleaning Summary:
# ...
# Original Rows:      4,999
# Duplicates Dropped: 2,641
# Nulls Dropped:      1
# Final Clean Rows:   2,357
# ...
#
# Real Data Sample (Complexity Check):
# ------------------------------
# Specialty:  Allergy / Immunology
#
# Transcription:
# ...

# %% [markdown]
# ## 3. Class Imbalance Analysis (Target Variable)

# %%
plt.figure(figsize=(12, 6))

# Top 10 Specialties
top_classes = df_clean['medical_specialty'].value_counts().head(10)
sns.barplot(x=top_classes.values, y=top_classes.index, palette='viridis', hue=top_classes.index)

# Formatting
plt.title('Top 10 Medical Specialties Distribution')
plt.xlabel('Number of Transcriptions')
plt.ylabel('Medical Specialty')
plt.legend([],[], frameon=False)
plt.show()

# %% [markdown]
# ## 4. Contexto Clínico y Vocabulario Dominante

# %%
# Calculate length in words
df_clean['transcription_length'] = df_clean['transcription'].apply(lambda x: len(str(x).split()))

# Key Metrics
mean_len = df_clean['transcription_length'].mean()
p95_len = df_clean['transcription_length'].quantile(0.95)

print("Transcription Length Statistics:")
print(f"Mean Length: {mean_len:.2f} words")
print(f"95th Percentile (P95): {p95_len:.2f} words")

# Visualization 1: Length Distribution
plt.figure(figsize=(12, 5))
sns.histplot(df_clean['transcription_length'], bins=50, kde=True, color='teal')
plt.axvline(mean_len, color='red', linestyle='--', label=f'Mean: {mean_len:.0f}')
plt.axvline(p95_len, color='orange', linestyle='--', label=f'P95: {p95_len:.0f}')

plt.title('Distribution of Transcription Lengths')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Visualization 2: WordCloud
majority_class = top_classes.index[0]
text_corpus = " ".join(df_clean[df_clean['medical_specialty'] == majority_class]['transcription'])

stop_words = set(stopwords.words('english'))

wordcloud = WordCloud(width=800, height=400, 
                      background_color='white', 
                      stopwords=stop_words, 
                      colormap='Blues').generate(text_corpus)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title(f'Frequent Vocabulary: {majority_class} (Context Check)')
plt.show()
# Out:
# Transcription Length Statistics:
# Mean Length: 458.27 words
# 95th Percentile (P95): 1032.20 words

# %% [markdown]
# ## 5. Análisis de longitud de transcripciones por especialidad

# %%
# Top 10 especialidades
top_specialties = df_clean['medical_specialty'].value_counts().head(10).index

# Crear dataframe para análisis
length_data = []
for specialty in top_specialties:
    lengths = df_clean[df_clean['medical_specialty'] == specialty]['transcription_length']
    length_data.append({
        'Specialty': specialty,
        'Mean': lengths.mean(),
        'Median': lengths.median(),
        'Std': lengths.std(),
        'Min': lengths.min(),
        'Max': lengths.max()
    })

length_df = pd.DataFrame(length_data).sort_values('Mean', ascending=False)
print("\nEstadísticas de longitud por especialidad:")
print(length_df.to_string(index=False))

# Visualización: Box plots por especialidad
plt.figure(figsize=(14, 6))

# Preparar datos para boxplot
specialty_lengths = [
    df_clean[df_clean['medical_specialty'] == spec]['transcription_length'].values
    for spec in top_specialties
]

# Crear boxplot
bp = plt.boxplot(specialty_lengths, 
                 labels=[spec[:20] + '...' if len(spec) > 20 else spec 
                        for spec in top_specialties],
                 patch_artist=True,
                 showmeans=True)

# Colorear las cajas
colors = plt.cm.Set3(np.linspace(0, 1, len(top_specialties)))
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

plt.xticks(rotation=45, ha='right')
plt.ylabel('Longitud (palabras)')
plt.title('Distribución de Longitud de Transcripciones por Especialidad')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# Test estadístico: ANOVA para ver si hay diferencias significativas
from scipy import stats

# Preparar datos para ANOVA
groups = [df_clean[df_clean['medical_specialty'] == spec]['transcription_length'].values 
          for spec in top_specialties]

f_stat, p_value = stats.f_oneway(*groups)

print("\n" + "="*50)
print("TEST ANOVA: ¿Difiere la longitud entre especialidades?")
print("="*50)
print(f"F-statistic: {f_stat:.2f}")
print(f"P-value: {p_value:.2e}")

if p_value < 0.05:
    print("\n✓ Resultado: HAY diferencias significativas en longitud entre especialidades")
    print("→ La longitud puede ser un feature útil para clasificación")
else:
    print("\nResultado: NO hay diferencias significativas")
    print("→ La longitud podría no ser discriminativa")
# Out:
# Estadísticas de longitud por especialidad:
#                      Specialty       Mean  Median        Std  Min  Max
#        Psychiatry / Psychology 829.235294   662.0 509.456047   13 1949
#                      Neurology 643.194030   524.0 398.880982  176 2460
#     Consult - History and Phy. 558.072727   466.0 330.806862    9 1922
#                     Orthopedic 520.339286   443.5 389.241793    3 1879
#               General Medicine 509.254777   482.0 238.242225    9 1403
#                        Surgery 489.625000   417.5 303.253528    2 2019
#          Pediatrics - Neonatal 469.942308   415.5 215.800054  103 1037
#                        Urology 406.532051   341.0 291.449247    2 2008
#  SOAP / Chart / Progress Notes 378.548611   318.5 211.394929    1 1068
#                      Radiology 273.431452   231.0 183.412643    1  960
# ...
# TEST ANOVA: ¿Difiere la longitud entre especialidades?
# ...
# F-statistic: 27.56
# P-value: 2.49e-45
#
# ...

# %% [markdown]
# ## 5. Análisis de N-gramas

# %%
# Función para obtener top N-gramas
def get_top_ngrams(corpus, n_gram_range, top_n=20, stop_words='english'):
    """
    Extrae los top N n-gramas de un corpus
    """
    vec = CountVectorizer(
        ngram_range=n_gram_range,
        stop_words=stop_words,
        max_features=5000
    ).fit(corpus)
    
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    
    return words_freq[:top_n]

# Preparar corpus (convertir a minúsculas)
corpus = df_clean['transcription'].str.lower().values

# Análisis de unigramas
print("\n" + "-"*50)
print("TOP 20 UNIGRAMAS (palabras individuales)")
print("-"*50)
unigrams = get_top_ngrams(corpus, (1, 1), top_n=20)
for word, freq in unigrams:
    print(f"{word:30s} : {freq:>6,}")

# Análisis de bigramas
print("\n" + "-"*50)
print("TOP 20 BIGRAMAS (pares de palabras)")
print("-"*50)
bigrams = get_top_ngrams(corpus, (2, 2), top_n=20)
for word, freq in bigrams:
    print(f"{word:30s} : {freq:>6,}")

# Análisis de trigramas
print("\n" + "-"*50)
print("TOP 20 TRIGRAMAS (tríos de palabras)")
print("-"*50)
trigrams = get_top_ngrams(corpus, (3, 3), top_n=20)
for word, freq in trigrams:
    print(f"{word:30s} : {freq:>6,}")

# Visualización: Comparación de N-gramas
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Unigramas
uni_words, uni_counts = zip(*unigrams[:15])
axes[0].barh(range(len(uni_words)), uni_counts, color='steelblue')
axes[0].set_yticks(range(len(uni_words)))
axes[0].set_yticklabels(uni_words)
axes[0].set_xlabel('Frecuencia')
axes[0].set_title('Top 15 Unigramas')
axes[0].invert_yaxis()

# Bigramas
bi_words, bi_counts = zip(*bigrams[:15])
axes[1].barh(range(len(bi_words)), bi_counts, color='coral')
axes[1].set_yticks(range(len(bi_words)))
axes[1].set_yticklabels(bi_words)
axes[1].set_xlabel('Frecuencia')
axes[1].set_title('Top 15 Bigramas')
axes[1].invert_yaxis()

# Trigramas
tri_words, tri_counts = zip(*trigrams[:15])
axes[2].barh(range(len(tri_words)), tri_counts, color='lightgreen')
axes[2].set_yticks(range(len(tri_words)))
axes[2].set_yticklabels(tri_words)
axes[2].set_xlabel('Frecuencia')
axes[2].set_title('Top 15 Trigramas')
axes[2].invert_yaxis()

plt.tight_layout()
plt.show()
# Out:
# --------------------------------------------------
# TOP 20 UNIGRAMAS (palabras individuales)
# --------------------------------------------------
# patient                        : 11,317
# right                          :  5,469
# left                           :  5,338
# history                        :  4,351
# procedure                      :  3,605
# normal                         :  3,430
# placed                         :  3,302
# pain                           :  2,683
# time                           :  1,992
# mg                             :  1,992
# noted                          :  1,988
# using                          :  1,923
# blood                          :  1,861
# performed                      :  1,854
# skin                           :  1,777
# anesthesia                     :  1,769
# incision                       :  1,678
# removed                        :  1,671
# used                           :  1,659
# year                           :  1,649
#
# ...

# %% [markdown]
# ## Problema y contexto
#
# La documentación clínica es un pilar de la atención médica moderna: diariamente se generan transcripciones que registran procedimientos, diagnósticos, tratamientos y evolución de pacientes. Sin embargo, clasificar manualmente estas transcripciones por especialidad médica es un proceso lento, costoso y propenso a inconsistencias, lo que dificulta la organización y recuperación eficiente de la información en sistemas de historias clínicas electrónicas.
#
# En este contexto, el procesamiento de lenguaje natural (NLP) permite automatizar la clasificación de texto clínico, reduciendo carga operativa y mejorando la disponibilidad de información para consulta y análisis. Para estudiar este problema, se utilizará el dataset mtsamples, con 2,357 transcripciones distribuidas en 39 especialidades, lo cual introduce retos representativos del mundo real: fuerte desbalance de clases (pocas especialidades concentran la mayoría de muestras), variación notable en longitud de los documentos y terminología especializada que difiere entre especialidades.
#
# El objetivo del proyecto es diseñar e implementar un sistema reproducible de clasificación automática de transcripciones por especialidad, acompañado de un pipeline MLOps que garantice trazabilidad y operación consistente: versionamiento de datos y modelos, seguimiento de experimentos y métricas, despliegue automatizado y monitoreo del rendimiento. Con ello, se busca una solución práctica y mantenible para organizar transcripciones médicas a escala, con criterios claros de evaluación y buenas prácticas de ingeniería aplicadas al aprendizaje automático.

# %% [markdown]
# ## Pregunta de negocio
# El proyecto parte de la siguiente pregunta central:
#
# ¿Es posible desarrollar un sistema automatizado de clasificación de transcripciones médicas por especialidad, utilizando técnicas de procesamiento de lenguaje natural y aprendizaje automático, que alcance un rendimiento comparable al juicio humano (F1-score > 0.6) incluso ante un desbalance significativo de clases, y que además sea desplegable, escalable y mantenible mediante prácticas MLOps?

# %% [markdown]
# ## Alcance del proyecto
#
# Con fines estrictamente académicos y de investigación en MLOps, el proyecto tiene el siguiente alcance:
#
# 1) Datos
# - Uso del dataset mtsamples (fuente pública).
# - 39 especialidades médicas.
# - 2,357 transcripciones tras limpieza (nulos/duplicados).
# - No se recolectarán datos primarios ni se intervendrán flujos clínicos reales.
#
# 2) Pipeline MLOps (reproducible)
# - Versionamiento de datos y artefactos con DVC.
# - Tracking de experimentos con MLflow o Weights & Biases (hiperparámetros, métricas y artefactos).
# - CI/CD básico con GitHub Actions para pruebas, validación y ejecución del pipeline.
#
# 3) Modelado y evaluación
# - Preprocesamiento de texto (normalización y tokenización).
# - Representación con TF-IDF + n-gramas; longitud del documento como feature auxiliar.
# - Modelos baseline: SVM y Random Forest con validación estratificada.
# - Manejo del desbalance: class weights, undersampling y/o SMOTE (según aplique).
# - Métricas: Macro F1 (principal), Weighted F1 y métricas por clase; matriz de confusión.
#
# 4) Entregables
# - Modelo versionado y reproducible.
# - Pipeline end-to-end ejecutable (entrenamiento → evaluación → registro de artefactos).
# - Demo de inferencia (CLI o script) para clasificar nuevas transcripciones.
#
# 5) Limitaciones
# - Prototipo académico: no es producto clínico ni sustituye criterio médico.
# - Sin integración con EMR/EHR, sin cumplimiento regulatorio (p. ej., HIPAA), sin SLAs de producción.
# - Enfoque en MLOps y baselines clásicos (sin transformers/BERT médico; sin monitoreo avanzado de drift en tiempo real).
#
# 6) Criterio de éxito
# - Lograr Macro F1 ≥ 0.6 en el conjunto de test y documentar resultados reproducibles con trazabilidad completa (datos, experimentos y modelo).
